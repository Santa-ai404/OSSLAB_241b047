# %%
from imblearn.over_sampling import SMOTE
import pandas as pd
data = {
'Study_Hours': [1, 2, 3, 4, 5, 6, 7],
'Result': [0, 0, 0, 0, 0, 1, 1]
}
df = pd.DataFrame(data)
X = df[['Study_Hours' ]]
y = df['Result']
print("Original Class Distribution")
print(y.value_counts())
smote = SMOTE(random_state=42, k_neighbors=1)
X_resampled, y_resampled = smote.fit_resample(x, y)
print("\nAfter Applying SMOTE")
print(y_resampled.value_counts())
resampled_df = pd.DataFrame(X_resampled, columns=['Study_Hours'])
resampled_df['Result'] = y_resampled
print("\nResampled Dataset")
print(resampled_df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from imblearn.over_sampling import SMOTE
#       2 import pandas as pd
#       3 data = {
#       4 'Study_Hours': [1, 2, 3, 4, 5, 6, 7],
#       5 'Result': [0, 0, 0, 0, 0, 1, 1]
#       6 }
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
pip install imbalanced-learn
# Out:
# ...
#      ---------------------------------------- 0.0/236.1 kB ? eta -:--:--
#      ----- --------------------------------- 30.7/236.1 kB 1.4 MB/s eta 0:00:01
#      --------------- ----------------------- 92.2/236.1 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 236.1/236.1 kB 1.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE
import pandas as pd
data = {
'Study_Hours': [1, 2, 3, 4, 5, 6, 7],
'Result': [0, 0, 0, 0, 0, 1, 1]
}
df = pd.DataFrame(data)
X = df[['Study_Hours' ]]
y = df['Result']
print("Original Class Distribution")
print(y.value_counts())
smote = SMOTE(random_state=42, k_neighbors=1)
X_resampled, y_resampled = smote.fit_resample(x, y)
print("\nAfter Applying SMOTE")
print(y_resampled.value_counts())
resampled_df = pd.DataFrame(X_resampled, columns=['Study_Hours'])
resampled_df['Result'] = y_resampled
print("\nResampled Dataset")
print(resampled_df)
# Out:
# Original Class Distribution
# Result
# 0    5
# 1    2
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 13
#      11 print(y.value_counts())
#      12 smote = SMOTE(random_state=42, k_neighbors=1)
# ---> 13 X_resampled, y_resampled = smote.fit_resample(x, y)
#      14 print("\nAfter Applying SMOTE")
#      15 print(y_resampled.value_counts())
#
# NameError: name 'x' is not defined
